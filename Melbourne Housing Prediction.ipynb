# %% [markdown]
# ### Data Loading and Description

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import sklearn as sks
import matplotlib.pyplot as plt

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../Downloads/"))

# Any results you write to the current directory are saved as output.
# Out:
# ['uTorrent.dmg', 'uTorrent.exe', '.DS_Store', 'Hands_On_Machine_Learning_with_Scikit_Le.pdf', '.localized', 'vlc-3.0.2.dmg', 'melb_data.csv', 'url.html', 'Black Panther 2018 NEW PROPER HD-TS X264-CPG', 'ios-11-wallpaper-1440x900-4k-sea-13659.jpg', 'data-visualization-using-tableau-public', 'logo', 'logo.png', 'algorithms-recommendation-systems', 'baros-maldives-wallpaper-1440x900-5k-4k-wallpaper-male-attols-best-hotels-of-3131.jpg', 'BX-CSV-Dump', 'Hands.Machine.Learning.Scikit.Learn.Tensorflow.5225.pdf']

# %%
data_path="../Downloads/melb_data.csv"
data=pd.read_csv(data_path)
data.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance      ...        Bathroom  Car  Landsize  \
# 0  Biggin  3/12/2016       2.5      ...             1.0  1.0     202.0
# 1  Biggin  4/02/2016       2.5      ...             1.0  0.0     156.0
# 2  Biggin  4/03/2017       2.5      ...             2.0  0.0     134.0
# 3  Biggin  4/03/2017       2.5      ...             2.0  1.0      94.0
# 4  Nelson  4/06/2016       2.5      ...             1.0  2.0     120.0
#
#    BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %% [markdown]
# ## Metadata about the columns
#
# Suburb: Suburb
#
# Address: Address
#
# Rooms: Number of rooms
#
# Price: Price in dollars
#
# Method: S - property sold; SP - property sold prior; PI - property passed in; PN - sold prior not disclosed; SN - sold not disclosed; NB - no bid; VB - vendor bid; W - withdrawn prior to auction; SA - sold after auction; SS - sold after auction price not disclosed. N/A - price or highest bid not available.
#
# Type: br - bedroom(s); h - house,cottage,villa, semi,terrace; u - unit, duplex; t - townhouse; dev site - development site; o res - other residential.
#
# SellerG: Real Estate Agent
#
# Date: Date sold
#
# Distance: Distance from CBD
#
# Regionname: General Region (West, North West, North, North east ...etc)
#
# Propertycount: Number of properties that exist in the suburb.
#
# Bedroom2 : Scraped # of Bedrooms (from different source)
#
# Bathroom: Number of Bathrooms
#
# Car: Number of carspots
#
# Landsize: Land Size
#
# BuildingArea: Building Size
#
# YearBuilt: Year the house was built
#
# CouncilArea: Governing council for the area
#
# Lattitude: Self explanitory
#
# Longtitude: Self explanitory

# %%
#Run once in the beggining to deleyte row with every feature missing
data[data.Postcode.isnull()&data.Distance.isnull()&data.Propertycount.isnull()]
# Out:
#        Unnamed: 0         Suburb           Address  Rooms Type     Price  \
# 14440       18523  Footscray Lot  2/16 Stafford St      2    u  710000.0
#
#       Method SellerG        Date  Distance      ...        Bathroom  Car  \
# 14440      S     Jas  15/07/2017       NaN      ...             NaN  NaN
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# 14440       NaN           NaN        NaN          NaN        NaN        NaN
#
#        Regionname  Propertycount
# 14440         NaN            NaN
#
# [1 rows x 22 columns]

# %%
#data.drop(data.index[14440], inplace=True)
data.iloc[14440]
# Out:
# Unnamed: 0                      18524
# Suburb                    Forest Hill
# Address                35 Panorama Dr
# Rooms                               4
# Type                                h
# Price                          945000
# Method                              S
# SellerG                           Ray
# Date                       15/07/2017
# Distance                         15.4
# Postcode                         3131
# Bedroom2                            4
# Bathroom                            2
# Car                                 2
# Landsize                          294
# BuildingArea                      194
# YearBuilt                        2010
# CouncilArea                Whitehorse
# Lattitude                    -37.8516
# Longtitude                    145.169
# Regionname       Eastern Metropolitan
# Propertycount                    4385
# Name: 14441, dtype: object

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             0
# Bedroom2          3468
# Bathroom          3470
# Car               3575
# Landsize          4792
# BuildingArea     10633
# YearBuilt         9437
# CouncilArea       6162
# Lattitude         3331
# Longtitude        3331
# Regionname           0
# Propertycount        0
# dtype: int64

# %%
index_data=data['Unnamed: 0']
continuous_data=data[['Rooms','Price','Distance','Postcode','Bedroom2','Bathroom','Car','BuildingArea','Landsize','Lattitude','Longtitude','Propertycount']]

categorical_data=data[['Suburb','Address','Type', 'Method','SellerG', 'CouncilArea','Regionname']]
    
time_data=data[['Date','YearBuilt']]
#print(continuous_data,categorical_data,time_data)
for i in range(3):
    if(i==0):
        print(continuous_data.head())
    elif(i==1):
        print(categorical_data.head())
    else:
        print(time_data.head())
# Out:
#    Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0      2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1      2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2      3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3      3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4      4  1600000.0       2.5    3067.0       3.0       1.0  2.0
#
#    BuildingArea  Landsize  Lattitude  Longtitude  Propertycount
# 0           NaN     202.0   -37.7996    144.9984         4019.0
# 1          79.0     156.0   -37.8079    144.9934         4019.0
# 2         150.0     134.0   -37.8093    144.9944         4019.0
# 3           NaN      94.0   -37.7969    144.9969         4019.0
# 4         142.0     120.0   -37.8072    144.9941         4019.0
#        Suburb           Address Type Method SellerG CouncilArea  \
# 0  Abbotsford      85 Turner St    h      S  Biggin       Yarra
# ...

# %%
continuous_data.isnull().sum()
# Out:
# Rooms                0
# Price                0
# Distance             0
# Postcode             0
# Bedroom2          3468
# Bathroom          3470
# Car               3575
# BuildingArea     10633
# Landsize          4792
# Lattitude         3331
# Longtitude        3331
# Propertycount        0
# dtype: int64

# %% [markdown]
# There are a lot of missing values that we will deal with later.
# For now lets plot the Target variable with the numeric variables

# %%
for i in continuous_data.columns :
    plt.figure()
    sns.lmplot(x="Price", y=i,data=data)
  
    plt.show()

# %% [markdown]
# #### Few points noted:
#
# Suburb: Suburb
# ##### Can we find the costiliest and least costly suburbs?
#
# Address: Address
# ##### Can we find the streets with the cosliest houses?
#
#
# Rooms: Number of rooms
# ##### By the plots above, its evident that till 5 bedrooms the prices are pretty much in a range
#
# Price: Price in dollars
#
# Method: S - property sold; SP - property sold prior; PI - property passed in; PN - sold prior not disclosed; SN - sold not disclosed; NB - no bid; VB - vendor bid; W - withdrawn prior to auction; SA - sold after auction; SS - sold after auction price not disclosed. N/A - price or highest bid not available.
# ##### Which is the cheapest way to accquire a house?
#
# Type: br - bedroom(s); h - house,cottage,villa, semi,terrace; u - unit, duplex; t - townhouse; dev site - development site; o res - other residential.
# ##### Which is the costliest and cheapest type of property?
#
# SellerG: Real Estate Agent
# ##### Who is making the maximum bucks? Whom should I go to fopr the best deals? Who has the best properties?
# Date: Date sold
# ##### Does this feature matter?
# Distance: Distance from CBD
# ##### Closer is costly as per the plots above
#
# Regionname: General Region (West, North West, North, North east ...etc)
# ##### Cheapest and cosliest suburbs
#
# Propertycount: Number of properties that exist in the suburb.
# #### ???
# Bedroom2 : Scraped # of Bedrooms (from different source)
# ##### By the plots above, its evident that more is pricey
#
#
# Bathroom: Number of Bathrooms
# ##### By the plots above, its evident that more is pricey
# Car: Number of carspots
# ##### By the plots above, its evident that more is pricey
#
# Landsize: Land Size
# ##### This needs mpore analysis
# BuildingArea: Building Size
# ##### Does this connect with suburb? is it constant for suburb or region(use pivot func)
#
# YearBuilt: Year the house was built
# ##### Are older houses cheaper?
#
#
# CouncilArea: Governing council for the area
# ##### Does this matter? Does this connect with suburb?(use pivot func)
# Lattitude&Longtitude: Use this for plotting multivariate analysis.

# %%
for i in continuous_data.columns :
    if(i in ['Rooms','Car',]):
        plt.figure()
        continuous_data.plot(x="Lattitude", y="Longtitude", kind="scatter", alpha=0.4,figsize=(12,10),c="Price",colormap="gist_rainbow",s=continuous_data[i],label=i,colorbar=True)
        plt.legend()
        plt.show()
    elif(i in['Landsize','Propertycount','BuildingArea']):
        plt.figure()
        continuous_data.plot(x="Lattitude", y="Longtitude", kind="scatter", alpha=0.4,figsize=(12,10),c="Price",colormap="gist_rainbow",s=continuous_data[i]/100,label=i,colorbar=True)
        plt.legend()
        plt.show()

# %% [markdown]
# ### Cleaning the data
